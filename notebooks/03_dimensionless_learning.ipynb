# %% [markdown]
# # 03 — 无量纲学习 / 可选 SINDy
#
# 比较仅无量纲特征的 ElasticNet 与全特征 XGBoost；可扩展 pysindy 符号回归。

# %%
import json
import pandas as pd
from pathlib import Path
ROOT = Path('..').resolve()
metrics = json.loads((ROOT / 'data_proc/models/training_metrics.json').read_text())
pd.DataFrame([{'model': k, **v} for k,v in metrics['metrics'].items() if isinstance(v, dict)])

# %% [markdown]
# 安装 pysindy 后可尝试:
# ```python
# # import pysindy as ps
# # library = ps.CustomLibrary(library_functions=[lambda x: x], function_names=[lambda x: 'x'])
# ```
